# %% [markdown]
# <a href="https://colab.research.google.com/github/vrishinjain/cs666student/blob/main/Copy_of_CS666_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo.png](data:image/png;base64,...)
# #Assignment 3

# %%
## YOUR NAME:Vrishin Jain
##

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ![SlicerScreenshot.jpg](data:image/jpeg;base64,...)**Task 1:** Download and install 3D Slicer [5 Points]

# %%
# 3D Slicer is available for Windows, Linux, and Mac here: https://slicer.org
# Please use the stable version 5.10 !

# %% [markdown]
# ![SlicerUltrasoundScreenshot.jpg](data:image/jpeg;base64,...)**Task 2:** Let's load some Ultrasound data! [5 Points]

# %%
# Please download this file: https://cs666.org/data/ultrasound.nrrd !
# Then, drag and drop the file into 3D Slicer and click OK.

# %%
# TODO Is this a traditional 3D ultrasound image?
# TODO: No, it is not a traditional 3D ultrasound image.
# Traditional 3D ultrasound shows a fully rendered 3D surface of the object, whereas this image displays multiple 2D slices from different planes of a 3D dataset.

# %% [markdown]
# **Task 3:** Visualize the ultrasound data! [15 Points]

# %%
# Please use the Volume Rendering module in 3D slicer to render the data.
# Then, activate Cropping and adjust the bounding box to show the fetus.
# Hint: The MRI Default color map creates a nice visual.

# %%
# TODO Please post a screenshot of your rendering in the text box below by
# using the Upload image button after double-click.

# %% [markdown]
# ![Screenshot 2026-03-29 000920.jpg](data:image/jpeg;base64,...)

# %%
#The volume rendering module was used to generate a 3D visualization of the ultrasound data.
#The MRI Default preset was applied to enhance visibility. Cropping was enabled and the bounding box was adjusted to isolate and clearly display the fetus.

# %% [markdown]
# **Task 4:** Segment the fetus! [25 Points]

# %%
# Switch to the Segment Editor module and Add to create a new segment.
# Select the PAINT ICON and activate Masking -> Editable Intensity Range.
# Hint: Adjust the DIAMETER for a smaller or larger brush.
# Hint: Adjust the lower range of the intensity slider under masking to not include the black background.
# Hint: Switch to 'Red Slice only' view and use the arrow keys to navigate through the slices.
#
# TODO: Mark the Fetus by drawing on each slice!
# Hint: Start at Slice ~83mm to ~112mm
# TODO: Take a screenshot of one slice after painting and upload it below.
# Hint: You can use the SPHERE BRUSH for 3D labeling but be careful!

# %% [markdown]
# ![Screenshot 2026-03-29 003538.jpg](data:image/jpeg;base64,...)

# %%
# TODO: Click on Show 3D.
# This will create a 3D mesh of your segmentation.
# TODO: Switch to '3D Only' view and take a screenshot of the segmented fetus in 3D!
# TODO: Upload the screenshot below.

# %% [markdown]
# ![Screenshot 2026-03-29 004423.jpg](data:image/jpeg;base64,...)

# %%
# The 3D rendering appears irregular due to noise and intensity variations in ultrasound data. Volume rendering produces a rough surface, which may look distorted compared to a clean segmented 3D model.

# %% [markdown]
# **Task 5:** Let's look at some Twins! The segmentation was actually made from MRI data rather than US! [10 Points]

# %%
# Please download the twin babies labelmap from https://cs666.org/data/labelmap2.nii !
# Load the data in 3D Slicer ..
# IMPORTANT: Make sure to check the LABELMAP checkbox during loading
# ..and convert it into a segmentation node with the
# Data Module by right-clicking on it.

# %%
# TODO: How many different labels are part of this data?
# TODO: There are 20 different labels in the dataset, each representing a different segmented region.

# %% [markdown]
# **Task 6:** Find the babies! [10 Points]

# %%
# TODO: Please identify the labelmap values for the body of each baby!
# TODO: Baby 1: 2
# TODO: Baby 2: 102

# %%
# TODO: Use the Segmentation module to show the 3D models of Baby 1 and 2.
# TODO: Take a screenshot of the 3D view and upload it below.

# %% [markdown]
# ![Baby1.jpg](data:image/jpeg;base64,...)![Baby2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Task 7:** Find and visualize some more structures! [10 Points]

# %%
# Now, we will look at some internal structures of each baby.
# TODO: Identify the labelmap values for the following structures:
#
# Baby 1:
#    Brain/Spinal Cord: 7
#    Eyes: 11
#    Lung: 12
#
# Baby 2:
#    Brain/Spinal Cord: 107
#    Eyes: 111
#    Lung: 106

# %%
# TODO: Show the 3D models of the above structures and upload a screenshot below!

# %% [markdown]
# ![Baby1Brain.jpg](data:image/jpeg;base64,...)![Baby1Lungs.jpg](data:image/jpeg;base64,...)![Baby1Eyes.jpg](data:image/jpeg;base64,...)![Baby2Spinal.jpg](data:image/jpeg;base64,...)![Baby2Brain.jpg](data:image/jpeg;base64,...)![Baby2Eyes.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![CTChest.jpg](data:image/jpeg;base64,...)**Task 8:** Run the TotalSegmentator! [10 Points]

# %%
# Please install the TotalSegmentator using the extension manager like we did in class!
# You can try to run it on the ultrasound image but it will not work! So, let's download
# the CT Chest sample data.
# Then, use the TotalSegmentator module to segment all structures! Switch to red-slice only layout
# and insert a screenshot here! Does this work well?


#Yes, the TotalSegmentator works well on CT data as it clearly segments multiple anatomical structures such as lungs, heart, and bones.

# %% [markdown]
# ![Talk2View.jpg](data:image/jpeg;base64,...)**Task 9:** Use Talk2View.com! [10 Points]

# %%
# Download https://cs666.org/data/mri.zip and unzip the file. Now, please visit
# https://app.talk2view.com/ and Upload the *.dcm files from this folder. Choose
# "Local Files" in the left combobox and then open the newly uploaded study with
# Talk2View. Then, please use the chat to figure out what the MRI scan shows and
# take a screenshot.

# %%
# TODO: What does the MRI scan show according to Talk2View?
# TODO: Based on the provided MRI image, here's an analysis:

#Anatomical Region: The image shows a sagittal view of a shoulder joint, specifically focusing on the glenohumeral joint (the ball-and-socket joint of the shoulder).

#Notable Findings:

#Glenohumeral Joint: The joint space appears relatively normal in width.
#Biceps Tendon: The long head of the biceps tendon is visible.
#Rotator Cuff: The rotator cuff muscles (supraspinatus, infraspinatus, teres minor, subscapularis) are visualized.
#Acromion: The acromion process is visible superiorly.
#Glenoid Labrum: The glenoid labrum is present.
#Biceps Tendon Sheath: The sheath surrounding the biceps tendon appears intact.
#Subacromial Bursa: A small amount of fluid is seen within the subacromial bursa, suggesting mild inflammation or fluid accumulation.
#Abnormalities or Areas of Interest:

#Joint Effusion/Bursitis: There is a moderate amount of fluid (darker signal) distending the subacromial bursa. This could indicate mild bursitis or fluid accumulation related to the joint.
#Disclaimer: This analysis is based solely on the provided image and is not a substitute for a formal radiological report or clinical evaluation by a qualified healthcare professional. A complete assessment would require correlation with the patient's history, symptoms, and potentially other imaging studies.

# %% [markdown]
# ![BonusTask.jpg](data:image/jpeg;base64,...)**Bonus Task:** Use Slicer Python to analyze the image data from Task 3 (ultrasound.nrrd). [33 Points]

# %%
# Activate the console with View -> Python Interactor.
# Now, you can run Python commands in 3D Slicer (don't run the commands here but in 3D Slicer!).
#

#
# 1) Grab the image data as a numpy array.
# Hint: You need to replace $MRML_ID with the correct value.
# Hint: You can find that value in the DATA module, if you activate 'Show MRML IDs'
#node = slicer.mrmlScene.GetNodeByID('$MRML_ID')
# data_as_array = slicer.util.arrayFromVolume(node)

#
# 2) Now, data_as_array is a numpy array containing the image data.
#    We can print the shape and also the max value.
# print(data_as_array.shape)
# TODO: SHAPE
# print(data_as_array.max())
# TODO: MAX

#
# 3) Please write numpy code to find the coordinates of the single pixel
# with the maximum value.
import numpy as np
# SHAPE: (143, 224, 238)
# MAX: 254

# coords = np.unravel_index(np.argmax(data_as_array), data_as_array.shape)
# OUTPUT: (114, 204, 54)

# %%
# You did it!!
#     ,------.
#     `-____-'        ,-----------.
#      ,i--i.         |           |
#     / @  @ \       /  HEE HEE!  |
#    | -.__.- | ___-'             J
#     \.    ,/ """"""""""""""""""'
#     ,\""""/.
#   ,'  `--'  `.
#  (_,i'    `i._)
#     |      |
#     |  ,.  |
#     | |  | |
#     `-'  `-'  -bodom-
